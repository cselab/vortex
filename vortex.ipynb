# %% [markdown]
# <a href="https://colab.research.google.com/github/cselab/vortex/blob/main/notebooks/vortex.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# %%sh
# apt-get update -qq
# apt-get install -qq imagemagick

# %%
# %%sh
# wget -q http://basilisk.fr/basilisk/basilisk.tar.gz
# tar zxf basilisk.tar.gz
# cd basilisk/src
# cp config.gcc config
# make ast && make qcc
# mkdir -p "$HOME/.local/bin"
# cp qcc "$HOME/.local/bin/"

# %%
# %%sh
# # rm -rf vortex
# git clone -q --depth 1 https://github.com/cselab/vortex.git

# %%
# %%sh
# cd vortex
# $HOME/.local/bin/qcc -disable-dimensions main.c -O2 -lm

# %%
# %%sh
# cd vortex
# ./a.out 0.5 0.5 1.0 0.6 0.8 -1.0

# %%
# %%sh
# cd vortex
# python post.py

# %%
# %%sh
# cd vortex
# convert a.*.png ../a.mp4
